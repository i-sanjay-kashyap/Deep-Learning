# %%
import tensorflow as tf
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
housing = fetch_california_housing()

X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state = 42)

X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state =42)

tf.random.set_seed(42)
norm_layer = tf.keras.layers.Normalization(input_shape = X_train.shape[1:])
model = tf.keras.Sequential([
    norm_layer,
    tf.keras.layers.Dense(50, activation = 'relu'),
    tf.keras.layers.Dense(50, activation = 'relu'),
    tf.keras.layers.Dense(50, activation = 'relu'),
    tf.keras.layers.Dense(1)
    ])

optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-3)
model.compile(loss = 'mse', optimizer = optimizer, metrics = ["RootMeanSquaredError"])
norm_layer.adapt(X_train)
history = model.fit(X_train, y_train, epochs = 20, validation_data = (X_valid, y_valid))

mse_test, rmse_test = model.evaluate(X_test, y_test)


X_new = X_test[:3]
y_pred = model.predict(X_new)
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - RootMeanSquaredError: 1.1722 - loss: 1.4642 - val_RootMeanSquaredError: 0.6174 - val_loss: 0.3812
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.6316 - loss: 0.3994 - val_RootMeanSquaredError: 0.6187 - val_loss: 0.3828
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.6023 - loss: 0.3630 - val_RootMeanSquaredError: 0.6414 - val_loss: 0.4114
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5837 - loss: 0.3410 - val_RootMeanSquaredError: 0.7624 - val_loss: 0.5813
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5714 - loss: 0.3267 - val_RootMeanSquaredError: 0.9075 - val_loss: 0.8235
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5614 - loss: 0.3152 - val_RootMeanSquaredError: 0.6488 - val_loss: 0.4210
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5537 - loss: 0.3067 - val_RootMeanSquaredError: 1.0977 - val_loss: 1.2049
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5494 - loss: 0.3019 - val_RootMeanSquaredError: 0.7284 - val_loss: 0.5306
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5444 - loss: 0.2965 - val_RootMeanSquaredError: 0.7696 - val_loss: 0.5923
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5408 - loss: 0.2925 - val_RootMeanSquaredError: 0.8618 - val_loss: 0.7427
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5393 - loss: 0.2909 - val_RootMeanSquaredError: 0.7719 - val_loss: 0.5959
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 0.5356 - loss: 0.2869 - val_RootMeanSquaredError: 0.5472 - val_loss: 0.2995
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - RootMeanSquaredError: 0.5320 - loss: 0.2831 - val_RootMeanSquaredError: 0.5734 - val_loss: 0.3287
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5299 - loss: 0.2808 - val_RootMeanSquaredError: 0.5252 - val_loss: 0.2758
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5272 - loss: 0.2780 - val_RootMeanSquaredError: 0.5817 - val_loss: 0.3384
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5250 - loss: 0.2757 - val_RootMeanSquaredError: 0.5325 - val_loss: 0.2836
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5234 - loss: 0.2740 - val_RootMeanSquaredError: 0.6116 - val_loss: 0.3741
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5209 - loss: 0.2714 - val_RootMeanSquaredError: 0.5429 - val_loss: 0.2947
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5188 - loss: 0.2692 - val_RootMeanSquaredError: 0.7987 - val_loss: 0.6379
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5178 - loss: 0.2682 - val_RootMeanSquaredError: 0.5312 - val_loss: 0.2821
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5326 - loss: 0.2838
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
